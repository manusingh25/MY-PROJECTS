# %%
import seaborn as sns
import pandas as pd
import matplotlib
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("C:/Users/Manu/Downloads/Employee_Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
sns.displot(df['Age'])
sns.displot(df['BusinessTravel'],color='pink')
sns.displot(df['MaritalStatus'],color='red')
sns.displot(df['PercentSalaryHike'],color='green')
sns.displot(df['JobSatisfaction'],color='yellow')
sns.displot(df['DistanceFromHome'],color='teal')
sns.displot(df['Gender'],color='orange')
plt.show()

# %%
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts().keys()
# Out:
# Index(['Male', 'Female'], dtype='object')

# %%
df['Gender'].value_counts().values
# Out:
# array([882, 588], dtype=int64)

# %%
plt.figure(figsize=(4,4))
plt.bar(list(df['Gender'].value_counts().keys()),list(df['Gender'].value_counts()),color=['pink','yellow'])
plt.show()

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
df['MaritalStatus'].value_counts().keys()
# Out:
# Index(['Married', 'Single', 'Divorced'], dtype='object')

# %%
df['MaritalStatus'].value_counts().values
# Out:
# array([673, 470, 327], dtype=int64)

# %%
plt.bar(list(df['MaritalStatus'].value_counts().keys()),list(df['MaritalStatus'].value_counts()),color=['red','blue','grey'])
plt.show()

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
df['BusinessTravel'].value_counts().keys()
# Out:
# Index(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype='object')

# %%
df['BusinessTravel'].value_counts().values
# Out:
# array([1043,  277,  150], dtype=int64)

# %%
plt.bar(list(df['BusinessTravel'].value_counts().keys()),list(df['BusinessTravel'].value_counts()),color=['yellow','pink','green'])
plt.show()

# %%
plt.figure(figsize=(4,4))
plt.pie(list(df['BusinessTravel'].value_counts()[0:3]),labels=list(df['BusinessTravel'].value_counts()[0:3].keys()),autopct='%0.1f%%',colors=['yellow','pink','green'])
plt.show()

# %%
x=df['BusinessTravel'].value_counts()[0:3].keys()
y=df['BusinessTravel'].value_counts()[0:3]

# %%
plt.figure(figsize=(4,4))
plt.pie(y,labels=x)
plt.pie(y,labels=x,autopct='%0.1f%%',colors=['yellow','pink','green'])
plt.pie([1],colors=['w'],radius=0.4)
plt.show()

# %%
df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['Department'].value_counts().keys()
# Out:
# Index(['Research & Development', 'Sales', 'Human Resources'], dtype='object')

# %%
df['Department'].value_counts().values
# Out:
# array([961, 446,  63], dtype=int64)

# %%
plt.bar(list(df['Department'].value_counts().keys()),list(df['Department'].value_counts()),color=['blue','teal','brown'])
plt.show()

# %%
plt.pie(list(df['Department'].value_counts()[0:3]),labels=list(df['Department'].value_counts()[0:3].keys()),autopct='%0.1f%%',colors=['blue','teal','brown'])
plt.show()

# %%
p=df['Department'].value_counts()[0:4].keys()
q=df['Department'].value_counts()

# %%
plt.figure(figsize=(4,4))
plt.pie(q,labels=p)
plt.pie(q,labels=p,autopct='%0.1f%%',colors=['purple','pink','green','red'])
plt.pie([1],colors='w',radius=0.5)
plt.show()

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
df['EducationField'].value_counts().keys()
# Out:
# Index(['Life Sciences', 'Medical', 'Marketing', 'Technical Degree', 'Other',
#        'Human Resources'],
#       dtype='object')

# %%
df['EducationField'].value_counts().values
# Out:
# array([606, 464, 159, 132,  82,  27], dtype=int64)

# %%
plt.figure(figsize=(8,5))
plt.bar(list(df['EducationField'].value_counts().keys()),list(df['EducationField'].value_counts()),color=['pink','yellow','red','blue','green','teal'])
plt.show()

# %%
plt.pie(list(df['EducationField'].value_counts()[0:6]),labels=list(df['EducationField'].value_counts().keys()[0:6]),
        autopct='%0.1f%%',colors =['pink','yellow','red','blue','green','purple'])
plt.show()

# %%
g=df['EducationField'].value_counts()[0:6].keys()
h=df['EducationField'].value_counts()

# %%
plt.figure(figsize=(4,4))
plt.pie(h,labels=g)
plt.pie(h,labels=g,autopct='%0.1f%%',colors=['pink','yellow','red','blue','green','purple'])
plt.pie([1],colors='w',radius=0.4)
plt.show()

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
plt.figure(figsize=(4,4))
plt.bar(list(df['Attrition'].value_counts().keys()),list(df['Attrition'].value_counts()),color=['pink','purple'])
plt.show()
